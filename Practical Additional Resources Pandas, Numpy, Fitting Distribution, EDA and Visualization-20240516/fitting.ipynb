# %% [markdown]
# # Reliability

# %% [markdown]
# ## Installation and upgrading
# To install reliability for the first time, open your command prompt and type:\
# pip install reliability\
# To upgrade a previous installation of relability to the most recent version, open your command prompt and type:\
# pip install --upgrade reliability

# %%
pip install reliability
# Out:
# Requirement already satisfied: reliability in /Users/user/opt/anaconda3/lib/python3.7/site-packages (0.5.6)
# Requirement already satisfied: pandas>=1.1.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.2.4)
# Requirement already satisfied: autograd>=1.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.3)
# Requirement already satisfied: matplotlib>=3.3.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (3.4.2)
# Requirement already satisfied: numpy>=1.19.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.20.3)
# Requirement already satisfied: mplcursors>=0.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (0.4)
# Requirement already satisfied: autograd-gamma>=0.5.0 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (0.5.0)
# Requirement already satisfied: scipy>=1.5.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.6.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.1.2->reliability) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.1.2->reliability) (2.8.1)
# Requirement already satisfied: future>=0.15.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from autograd>=1.3->reliability) (0.18.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (2.4.6)
# Requirement already satisfied: pillow>=6.2.0 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (7.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (0.10.0)
# Requirement already satisfied: six>=1.5 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.2->reliability) (1.14.0)
# Requirement already satisfied: setuptools in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.2->reliability) (46.0.0.post20200309)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade reliability
# Out:
# Requirement already up-to-date: reliability in /Users/user/opt/anaconda3/lib/python3.7/site-packages (0.5.6)
# Requirement already satisfied, skipping upgrade: autograd-gamma>=0.5.0 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (0.5.0)
# Requirement already satisfied, skipping upgrade: pandas>=1.1.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.2.4)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.3.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (3.4.2)
# Requirement already satisfied, skipping upgrade: autograd>=1.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.3)
# Requirement already satisfied, skipping upgrade: scipy>=1.5.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.6.3)
# Requirement already satisfied, skipping upgrade: mplcursors>=0.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (0.4)
# Requirement already satisfied, skipping upgrade: numpy>=1.19.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from reliability) (1.20.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.1.2->reliability) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.1.2->reliability) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (2.4.6)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (7.0.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from matplotlib>=3.3.2->reliability) (0.10.0)
# Requirement already satisfied, skipping upgrade: future>=0.15.2 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from autograd>=1.3->reliability) (0.18.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.2->reliability) (1.14.0)
# Requirement already satisfied, skipping upgrade: setuptools in /Users/user/opt/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.3.2->reliability) (46.0.0.post20200309)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Fitting a Normal distribution to data
from reliability.Distributions import Normal_Distribution
from reliability.Fitters import Fit_Normal_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Normal_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Normal_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#        Mu         50.6845         5.36868   40.1621    61.207
#     Sigma         16.9773         3.79618   10.9531   26.3148
#
# Goodness of fit    Value
#  Log-likelihood -42.5082
#            AICc  90.7307
#             BIC  89.6216
#              AD  1.61514

# %%
from reliability.Distributions import Weibull_Distribution
from reliability.Fitters import Fit_Weibull_2P
from reliability.Probability_plotting import plot_points
import matplotlib.pyplot as plt

# %%
# Fitting a specific distribution to data
from reliability.Fitters import Fit_Weibull_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Weibull_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         56.6822         6.06257   45.9626   69.9019
#      Beta         3.14168        0.733552   1.98799   4.96489
#
# Goodness of fit    Value
#  Log-likelihood -42.4263
#            AICc  90.5669
#             BIC  89.4578
#              AD  1.55129

# %%
from reliability.Distributions import Weibull_Distribution
from reliability.Fitters import Fit_Weibull_3P
from reliability.Other_functions import make_right_censored_data, histogram
import matplotlib.pyplot as plt

# %%
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]

# %%
wbf = Fit_Weibull_3P(failures=data) # fit the Weibull_3P distribution
plt.show()
# Out:
# Results from Fit_Weibull_3P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         16.8461         8.66683   6.14585   46.1762
#      Beta        0.627193        0.179692   0.35771   1.09969
#     Gamma         30.7434     0.000157047   30.7431   30.7437
#
# Goodness of fit    Value
#  Log-likelihood -38.2934
#            AICc  86.5868
#             BIC  83.4946
#              AD  2.10334

# %%
# Fitting a specific distribution to data
from reliability.Fitters import Fit_Gamma_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Gamma_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Gamma_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         5.13887         2.31883   2.12216   12.4439
#      Beta         9.86298         4.33828   4.16488   23.3568
#
# Goodness of fit   Value
#  Log-likelihood -41.655
#            AICc 89.0243
#             BIC 87.9152
#              AD 1.49099

# %%
# Fitting a specific distribution to data
from reliability.Fitters import Fit_Normal_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Normal_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Normal_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#        Mu         50.6845         5.36868   40.1621    61.207
#     Sigma         16.9773         3.79618   10.9531   26.3148
#
# Goodness of fit    Value
#  Log-likelihood -42.5082
#            AICc  90.7307
#             BIC  89.6216
#              AD  1.61514

# %%
# Fitting a specific distribution to data
from reliability.Distributions import Weibull_Distribution
from reliability.Fitters import Fit_Lognormal_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Lognormal_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Lognormal_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#        Mu         3.87407       0.0997739   3.67852   4.06963
#     Sigma        0.315513       0.0705608  0.203543  0.489078
#
# Goodness of fit    Value
#  Log-likelihood -41.3936
#            AICc  88.5014
#             BIC  87.3923
#              AD  1.45137

# %%
# Fitting a specific distribution to data
from reliability.Distributions import Exponential_Distribution
from reliability.Fitters import Fit_Exponential_1P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Exponential_1P(failures=data)
plt.show()
# Out:
# Results from Fit_Exponential_1P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#    Lambda       0.0210965       0.0066713 0.0113511 0.0392088
#  1/Lambda         47.4012         14.9896   25.5045   88.0975
#
# Goodness of fit    Value
#  Log-likelihood -49.2791
#            AICc  101.058
#             BIC  100.861
#              AD  3.48874

# %%
# Fitting a specific distribution to data
from reliability.Distributions import Exponential_Distribution
from reliability.Fitters import Fit_Exponential_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Exponential_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Exponential_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#    Lambda       0.0501481       0.0158582 0.0269824 0.0932027
#  1/Lambda         19.9409         6.30587   10.7293   37.0611
#     Gamma         30.7434               0   30.7434   30.7434
#
# Goodness of fit    Value
#  Log-likelihood -39.9278
#            AICc    85.57
#             BIC  84.4608
#              AD   1.7739

# %%
from reliability.Fitters import Fit_Everything
data = [4,4,2,4,7,4,1,2,7,1,4,3,6,6,6,3,2,3,4,3,2,3,2,4,6,5,5,2,4,3] # created using Weibull_Distribution(alpha=5,beta=2), and rounded to nearest int
Fit_Everything(failures=data, show_histogram_plot=False, show_probability_plot=False, show_PP_plot=False)
plt.show()
# Out:
# Results from Fit_Everything:
# Analysis method: MLE
# Failures / Right censored: 30/0 (0% right censored)
#
#   Distribution    Alpha    Beta   Gamma      Mu    Sigma   Lambda  Log-likelihood    AICc     BIC      AD
#     Weibull_2P  4.21932 2.43761                                          -56.6259 117.696 120.054 1.04805
#       Gamma_2P 0.816684 4.57133                                          -56.9801 118.405 120.763 1.06592
#      Normal_2P                          3.73333  1.65193                 -57.6266 119.698 122.056 1.18539
#   Lognormal_2P                          1.20392 0.503628                 -58.1088 120.662  123.02 1.19881
#     Weibull_3P  3.61252 2.02388 0.53024                                  -56.4219 119.767 123.047 1.04948
# Loglogistic_2P  3.45096 3.48793                                          -58.3223 121.089 123.447  1.0561
#       Gamma_3P 0.816684 4.57133       0                                  -56.9801 120.883 124.164 1.06592
#   Lognormal_3P                        0 1.20392 0.503628                 -58.1088 123.141 126.421 1.19881
# Loglogistic_3P  3.45096 3.48793       0                                  -58.3223 123.568 126.848  1.0561
# Exponential_2P                   0.9999                   0.36584        -60.1668 124.778 127.136 3.11235
#      Gumbel_2P                          4.58389  1.65599                 -60.5408 125.526 127.884 1.57958
# Exponential_1P                                           0.299846        -69.7173 141.578 142.836 5.89119

# %%
from reliability.Distributions import Normal_Distribution
from reliability.Probability_plotting import Normal_probability_plot
import matplotlib.pyplot as plt
dist = Normal_Distribution(mu=50,sigma=10)
dist.CDF(linestyle='--',label='True CDF') #this is the actual distribution provided for comparison
failures = dist.random_samples(100)
Normal_probability_plot(failures=failures) #generates the probability plot
plt.show()

# %%
#1
from reliability.Fitters import Fit_Weibull_2P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Weibull_2P(failures=data)
plt.show()
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Failures / Right censored: 10/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         56.6822         6.06257   45.9626   69.9019
#      Beta         3.14168        0.733552   1.98799   4.96489
#
# Goodness of fit    Value
#  Log-likelihood -42.4263
#            AICc  90.5669
#             BIC  89.4578
#              AD  1.55129

# %%
#2
from reliability.Fitters import Fit_Weibull_3P
import matplotlib.pyplot as plt
data = [42.1605147, 51.0479599, 41.424553, 35.0159047, 87.3087644, 30.7435371, 52.2003467, 35.9354271, 71.8373629, 59.171129]
wb = Fit_Weibull_3P(failures=data)
plt.show()
# Out:
# Results from Fit_Weibull_3P (95% CI):
#            Point Estimate  Standard Error   Lower CI   Upper CI
# Parameter
# Alpha           16.846448        8.667081   6.145910  46.177506
# Beta             0.627194        0.179692   0.357711   1.099695
# Gamma           30.743437        0.000157  30.743129  30.743745
# Log-Likelihood: -38.29341983990782

# %%
from reliability.Fitters import Fit_Everything
data = [4,4,2,4,7,4,1,2,7,1,4,3,6,6,6,3,2,3,4,3,2,3,2,4,6,5,5,2,4,3] # created using Weibull_Distribution(alpha=5,beta=2), and rounded to nearest int
Fit_Everything(failures=data, show_histogram_plot=False, show_probability_plot=False, show_PP_plot=False)
# Out:
# Results from Fit_Everything:
# Analysis method: MLE
# Failures / Right censored: 30/0 (0% right censored)
#
#   Distribution    Alpha    Beta   Gamma      Mu    Sigma   Lambda  Log-likelihood    AICc     BIC      AD
#     Weibull_2P  4.21932 2.43761                                          -56.6259 117.696 120.054 1.04805
#       Gamma_2P 0.816684 4.57133                                          -56.9801 118.405 120.763 1.06592
#      Normal_2P                          3.73333  1.65193                 -57.6266 119.698 122.056 1.18539
#   Lognormal_2P                          1.20392 0.503628                 -58.1088 120.662  123.02 1.19881
#     Weibull_3P  3.61252 2.02388 0.53024                                  -56.4219 119.767 123.047 1.04948
# Loglogistic_2P  3.45096 3.48793                                          -58.3223 121.089 123.447  1.0561
#       Gamma_3P 0.816684 4.57133       0                                  -56.9801 120.883 124.164 1.06592
#   Lognormal_3P                        0 1.20392 0.503628                 -58.1088 123.141 126.421 1.19881
# Loglogistic_3P  3.45096 3.48793       0                                  -58.3223 123.568 126.848  1.0561
# Exponential_2P                   0.9999                   0.36584        -60.1668 124.778 127.136 3.11235
#      Gumbel_2P                          4.58389  1.65599                 -60.5408 125.526 127.884 1.57958
# Exponential_1P                                           0.299846        -69.7173 141.578 142.836 5.89119

# %% [markdown]
# $$\begin{matrix}
# Distribution & Mean & Variance\\
# Normal & \mu & \sigma^{2} \\
# \end{matrix}$$

# %%
# Out:
# <function dir>
